# %%
import dotenv
dotenv.load_dotenv()

import os
from googleapiclient.discovery import build

GOOGLE_API_KEY = os.environ.get("GOOGLE_API_KEY")
GOOGLE_CSE_ID = os.environ.get("GOOGLE_CSE_ID")

# %%
query = "サステナビリティ 技術 キーワード after:2023/07/01"
query = "Latest sustainability-related technologies after:2023/07/01"
query = "Latest sustainability-related M&A after:2023/07/01"
query = "Technologies, latest trends, and challenges facing sustainability after:2023/07/01"

# Google Custom Search API を使って検索
service = build("customsearch", "v1", developerKey=GOOGLE_API_KEY)
res = service.cse().list(q=query, cx=GOOGLE_CSE_ID).execute()

# %%
links = [s['link'] for s in res['items']]
links = [
"https://www.asahi.com/sdgs/",
"https://www.bbc.com/news/science_and_environment",
"https://esgnews.com/",
"https://sustainabilitymag.com/esg",
"https://sustainablejapan.jp/news",
"https://esgjournaljapan.com/",
]
links
# Out:
# ['https://www.asahi.com/sdgs/',
#  'https://www.bbc.com/news/science_and_environment',
#  'https://esgnews.com/',
#  'https://sustainabilitymag.com/esg',
#  'https://sustainablejapan.jp/news',
#  'https://esgjournaljapan.com/']

# %%
# スニペット
# from langchain.docstore.document import Document
# snippets = [s['snippet'] for s in res['items']]
# print(snippets)
# documents =  []
# for item in range(len(snippets)):
#     page = Document(
#         page_content = res['items'][item]['snippet'],
#         # metadata = res['items'][item],
#         )
#     documents.append(page)
# print(documents)

# スクレピング(TODO:動かない)
# from langchain_community.document_loaders import UnstructuredURLLoader
# loader = UnstructuredURLLoader(urls=links)
# documents = loader.load()
# print(documents)

# %%
# スクレピング
import requests
from bs4 import BeautifulSoup
from langchain.docstore.document import Document

# Requestsを利用してWebページを取得する
documents = [Document(page_content = BeautifulSoup(requests.get(link).text.replace('\n','').replace('\t','').replace('  ',' '), 'html.parser').text) for link in links]
print(documents)
# Out:
# [Document(page_content='  朝日新聞SDGs ACTION!：サステナビリティに取り組む人に伴走するメディア                      SDGsとは 取り組み事例 インタビュー 解説 連載 キーワード プロジェクト ブランド イベント 脱炭素計画 チェンジメーカーズ ウェルビーイング ローカル みんなのURL     SDGsとは 取り組み事例 インタビュー 解説 連載 キーワード プロジェクト ブランド イベント 脱炭素計画 チェンジメーカーズ ウェルビーイング ローカル みんなのURL         編集部へのお問い合わせはこちら       検索                         SDGsと民主主義、微妙な距離感の背景事情\u3000村上芽の「深く知るSDGs」【7】           人工飼育開始から60年\u300022羽を山に戻すためヘリは飛んだ\u3000ライチョウ復活作戦【15】          人類滅亡まで「残り90秒」、2024年も過去最短を維持\u3000米誌が「終末時計」発表          「世界で最も持続可能な100社」に日本からエーザイなど3社\u3000カナダの調査会社が発表          ステークホルダーとは\u3000意味や種類、使い方を事例付きで徹底解説              \r   【2/8リアル開催・録画配信あり＝参加募集中】TCFD開示やってみました\u3000朝日新聞社の事例を紹介\r              2024.02.05             ファッションとサステナビリティを融合\u3000商社・豊島がECサイトで目指すもの           豊島営業企画室／渡邉美和                    商品・サービス                               ファッション                               つくる・つかう                       2024.02.02             ダイコク電機の「SDGs自分ごと化」プロジェクト\u3000SDGs起点のイノベーションを目指して           Sponsored by ダイコク電機株式会社            2024.02.01             日本が参考にするべき食品ロス削減の国家戦略\u3000アメリカの取り組みを読み解く           食品ロス問題ジャーナリスト／井出留美                    食品ロス                               気候変動                               政治・行政                               海外                       2024.02.01             TNFDアーリーアダプター（早期採用者）に320社・団体\u3000日本から80社、国別で最多に           編集部                    環境                               生物多様性                               サステナビリティ情報開示                       2024.01.31             アシックスは「GHG排出量世界最少のスニーカー」をどう実現したか\u3000ビジネスパーソンのためのSDGs講座【26】           横田アソシエイツ代表取締役／横田浩一                    環境                               脱炭素・カーボンニュートラル                               脱炭素計画                               商品・サービス                       2024.01.30             脳科学の最前線「ブレインテック」の世界\u3000藤田康人のウェルビーイング解体新書【21】           インテグレート代表取締役CEO／藤田康人                    ウェルビーイング                               経済成長                               大学・研究機関                               商品・サービス                       2024.01.30             ステークホルダーとは\u3000意味や種類、使い方を事例付きで徹底解説           湊総合法律事務所所長弁護士／湊信明                    サステナブル経営                               パートナーシップ                       2024.01.29             大阪・関西万博を使い倒す!?\u3000理想の未来を“共創”で世界に発信           Sponsored by ２０２５年日本国際博覧会協会            2024.01.26             人類滅亡まで「残り90秒」、2024年も過去最短を維持\u3000米誌が「終末時計」発表           編集部                    平和・公正                               環境                               調査・統計                       2024.01.25             「世界で最も持続可能な100社」に日本からエーザイなど3社\u3000カナダの調査会社が発表           編集部                    サステナブル経営                               海外                               調査・統計                       2024.01.25             人工飼育開始から60年\u300022羽を山に戻すためヘリは飛んだ\u3000ライチョウ復活作戦【15】           山岳ジャーナリスト／近藤幸夫                    生物多様性                               環境                       2024.01.24             SDGsと民主主義、微妙な距離感の背景事情\u3000村上芽の「深く知るSDGs」【7】            日本総合研究所エクスパート／村上芽                    政治・行政                               平和・公正                       2024.01.23             COP28で「化石燃料からの脱却」へ初の合意\u3000ドイツでは賛否分かれる\u3000熊谷徹のヨーロッパSDGリポート【13】           在独ジャーナリスト／熊谷徹                    環境                               気候変動                               脱炭素・カーボンニュートラル                               脱炭素計画                               海外                       2024.01.23             ブルーアンモニアとは？\u3000期待される理由や日本企業の活用事例を解説           環境活動家／後藤美里                    エネルギー                               環境                               アイデア・技術                       2024.01.22             【2/9リアル開催セミナー＆ワークショップ】カーボンニュートラル時代の企業に求められる新たなコミュニケーション術とは           編集部                    環境                               脱炭素・カーボンニュートラル                               脱炭素計画                       2024.01.22             里山が持つ新たな価値創造とは？\u3000第1回「イオンSATOYAMAフォーラム」採録           Sponsored by 公益財団法人イオン環境財団                    生物多様性                               ウェルビーイング                               大学・研究機関                         ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

# テキストスプリッターを作成する
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=100,
)
docs = text_splitter.split_documents(documents)
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(docs, embeddings)

query = "Technologies, latest trends, and challenges facing sustainability."
docs = db.similarity_search(query)
docs
# Out:
# [Document(page_content='sustainability space that connects the world’s most sustainable brands & projects and their most senior executives with the latest trends as the sustainability market pivots towards technology and digital transformation.Join CommunityContentContentMoreMoreSocialsLinkedInTwitterFacebookInstagramYouTubeAdvertise with BizClikUser AgreementPrivacy Policy'),
#  Document(page_content='social and governance…#sustainability#esg#susliveESGExclusive Video: Sustainability LIVE Circular Economy ForumESGExclusive Video: Is ESG tarnished by the demand for finance?ESGReckitt’s marketing-led approach to product sustainabilitySustainability Magazine is a Digital Community for the global sustainability space that connects the world’s most sustainable brands & projects and their most'),
#  Document(page_content='requirementsLifetime of Achievement: Al GorePrivate equity and ESG: five trends and predictions for 2024BlackRock lawsuit recognises the importance of ESG in the USCanon’s Corporate ESG Strategy Supports Coral Reef ResearchCanon Europe Backs a Coral Reef Research Project, Acting as a Physical Carbon Offset With Long-Term Sustainability Implications for Years to Come…Global Sustainability & ESG'),
#  Document(page_content="Latest 'ESG' News & Feature Articles | Sustainability MagazineFindAdvertiseEditorialESGFeaturedMeet the Judges: The Global Sustainability & ESG Awards 2024Sustainability Magazine & Sustainability LIVE announces the judging panel for The Global Sustainability & ESG Awards 2024 and it's an exciting line-up!!…FeaturedMeet the Judges: The Global Sustainability & ESG Awards 2024Sustainability Magazine")]

# %%
from langchain import hub
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

vectorstore = Chroma.from_documents(documents=docs, embedding=OpenAIEmbeddings())

# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
query = "From the following text, please extract characteristic keywords related to sustainability-related technologies."
# query = "以下の文章を日本語で要約してください。"
rag_chain.invoke(query)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[88], line 27
#      25 query = "From the following text, please extract characteristic keywords related to sustainability-related technologies."
#      26 # query = "以下の文章を日本語で要約してください。"
# ---> 27 rag_chain.invoke(query)
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\runnables\base.py:2053, in RunnableSequence.invoke(self, input, config)
#    2051 try:
#    2052     for i, step in enumerate(self.steps):
# -> 2053         input = step.invoke(
#    2054             input,
#    2055             # mark each step as a child run
#    2056             patch_config(
#    2057                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2058             ),
#    2059         )
#    2060 # finish the root run
#    2061 except BaseException as e:
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:166, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     155 def invoke(
#     156     self,
#     157     input: LanguageModelInput,
#    (...)
#     161     **kwargs: Any,
#     162 ) -> BaseMessage:
#     163     config = ensure_config(config)
#     164     return cast(
#     165         ChatGeneration,
# --> 166         self.generate_prompt(
#     167             [self._convert_input(input)],
#     168             stop=stop,
#     169             callbacks=config.get("callbacks"),
#     170             tags=config.get("tags"),
#     171             metadata=config.get("metadata"),
#     172             run_name=config.get("run_name"),
#     173             **kwargs,
#     174         ).generations[0][0],
#     175     ).message
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:544, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     536 def generate_prompt(
#     537     self,
#     538     prompts: List[PromptValue],
#    (...)
#     541     **kwargs: Any,
#     542 ) -> LLMResult:
#     543     prompt_messages = [p.to_messages() for p in prompts]
# --> 544     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:408, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     406         if run_managers:
#     407             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 408         raise e
#     409 flattened_outputs = [
#     410     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     411     for res in results
#     412 ]
#     413 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     395 for i, m in enumerate(messages):
#     396     try:
#     397         results.append(
# --> 398             self._generate_with_cache(
#     399                 m,
#     400                 stop=stop,
#     401                 run_manager=run_managers[i] if run_managers else None,
#     402                 **kwargs,
#     403             )
#     404         )
#     405     except BaseException as e:
#     406         if run_managers:
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:577, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     573     raise ValueError(
#     574         "Asked to cache, but no cache found at `langchain.cache`."
#     575     )
#     576 if new_arg_supported:
# --> 577     return self._generate(
#     578         messages, stop=stop, run_manager=run_manager, **kwargs
#     579     )
#     580 else:
#     581     return self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_openai\chat_models\base.py:451, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     445 message_dicts, params = self._create_message_dicts(messages, stop)
#     446 params = {
#     447     **params,
#     448     **({"stream": stream} if stream is not None else {}),
#     449     **kwargs,
#     450 }
# --> 451 response = self.client.create(messages=message_dicts, **params)
#     452 return self._create_chat_result(response)
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\openai\_utils\_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     269             msg = f"Missing required argument: {quote(missing[0])}"
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\openai\resources\chat\completions.py:659, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     608 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     609 def create(
#     610     self,
#    (...)
#     657     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     658 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 659     return self._post(
#     660         "/chat/completions",
#     661         body=maybe_transform(
#     662             {
#     663                 "messages": messages,
#     664                 "model": model,
#     665                 "frequency_penalty": frequency_penalty,
#     666                 "function_call": function_call,
#     667                 "functions": functions,
#     668                 "logit_bias": logit_bias,
#     669                 "logprobs": logprobs,
#     670                 "max_tokens": max_tokens,
#     671                 "n": n,
#     672                 "presence_penalty": presence_penalty,
#     673                 "response_format": response_format,
#     674                 "seed": seed,
#     675                 "stop": stop,
#     676                 "stream": stream,
#     677                 "temperature": temperature,
#     678                 "tool_choice": tool_choice,
#     679                 "tools": tools,
#     680                 "top_logprobs": top_logprobs,
#     681                 "top_p": top_p,
#     682                 "user": user,
#     683             },
#     684             completion_create_params.CompletionCreateParams,
#     685         ),
#     686         options=make_request_options(
#     687             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     688         ),
#     689         cast_to=ChatCompletion,
#     690         stream=stream or False,
#     691         stream_cls=Stream[ChatCompletionChunk],
#     692     )
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\openai\_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\openai\_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\openai\_base_client.py:980, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     977         err.response.read()
#     979     log.debug("Re-raising status error")
# --> 980     raise self._make_status_error_from_response(err.response) from None
#     982 return self._process_response(
#     983     cast_to=cast_to,
#     984     options=options,
#    (...)
#     987     stream_cls=stream_cls,
#     988 )
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-4-turbo` does not exist', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
from langchain_core.prompts import ChatPromptTemplate
vectorstore = FAISS.from_texts(
    BeautifulSoup(requests.get(links[0]).text.replace('\n',''), 'html.parser').text.replace(' ',''), embedding=OpenAIEmbeddings()
)
retriever = vectorstore.as_retriever()

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

model = ChatOpenAI()

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

chain.invoke("以下の文章を日本語で要約してください。")
# Out:
# 'Answer: 約日'

# %%
# データフレームやリストでテキストを与える
texts = ["これはテキストの例です。", "Langchainは素晴らしいツールです。", "Pythonは人気のあるプログラミング言語です。"]

# ドキュメントローダーを作成する
from langchain.document_loaders import UnstructuredFileLoader
doc_loader = UnstructuredFileLoader(file_extension="txt", encoding="utf-8")

# テキストスプリッターを作成する
from langchain.text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(split_length=10, overlap_length=2)

# ベクトルストアを作成する
from langchain.vector_stores import FAISS
vector_store = FAISS(dimension=768, index_type="Flat")

# チェーンを作成する
from langchain.chains import RetrievalQAWithSourcesChain
chain = RetrievalQAWithSourcesChain(language_model="cl-tohoku/bert-base-japanese", prompt_template="{question}\n{answer}")

# ドキュメントローダーにテキストを渡して文書を読み込む
documents = doc_loader.load(texts)

# テキストスプリッターに文書を渡して分割する
chunks = text_splitter.split(documents)

# ベクトルストアに分割した文書のベクトルを保存する
vector_store.save(chunks)

# ユーザーの質問に対してチェーンを実行する
question = "Langchainは何をするツールですか？"
answer = chain.execute(question, vector_store)
print(answer)

# %%
import dotenv
import nest_asyncio
nest_asyncio.apply()
dotenv.load_dotenv()

from langchain_community.document_loaders import AsyncChromiumLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain_community.document_loaders import AsyncHtmlLoader
from langchain_community.document_transformers import Html2TextTransformer

from langchain_openai import ChatOpenAI

from langchain.chains import create_extraction_chain

import pprint

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.retrievers.web_research import WebResearchRetriever
from langchain_community.utilities import GoogleSearchAPIWrapper
from langchain_community.vectorstores import Chroma
from langchain_openai import ChatOpenAI, OpenAIEmbeddings


from langchain.indexes import GraphIndexCreator
from langchain_openai import OpenAI
from langchain.chains import GraphQAChain

# %%
urls = [
# "https://www.asahi.com/sdgs/",
"https://www.bbc.com/news/science_and_environment",
"https://esgnews.com/",
"https://sustainabilitymag.com/esg",
"https://sustainablejapan.jp/news",
"https://esgjournaljapan.com/",
]

# %%
# 複数URLのスクレイピング

# %%
schema = {
    "properties": {
        "news_article_title": {"type": "string"},
        "news_article_summary": {"type": "string"},
    },
    "required": ["news_article_title", "news_article_summary"],
}

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")

def extract(content: str, schema: dict):
    return create_extraction_chain(schema=schema, llm=llm).run(content)


def scrape_with_playwright(urls, schema):
    loader = AsyncHtmlLoader(urls)
    docs = loader.load()
    bs_transformer = BeautifulSoupTransformer()
    docs_transformed = bs_transformer.transform_documents(
        docs, tags_to_extract=["span"]
    )
    print("Extracting content with LLM")

    # Grab the first 1000 tokens of the site
    splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=1000, chunk_overlap=0, add_start_index=True
    )
    splits = splitter.split_documents(docs_transformed)

    # Process the first split
    extracted_content = extract(schema=schema, content=splits[0].page_content)
    pprint.pprint(extracted_content)
    return extracted_content

extracted_content = scrape_with_playwright(urls, schema=schema)
# Out:
# Fetching pages: 100%|##########| 5/5 [00:06<00:00,  1.22s/it]
# Extracting content with LLM
# /Users/tmina/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# [{'news_article_summary': 'A robot plane will be used to map the mysteries of '
#                           'Antarctica.',
#   'news_article_title': 'Antarctica mysteries to be mapped by robot plane'},
#  {'news_article_summary': "A black gunk is polluting the 'Bake Off' stream.",
#   'news_article_title': "What's the black gunk polluting the 'Bake Off' "
#                         'stream?'},
#  {'news_article_summary': 'The question of whether more British homes should '
#                           'be built using straw is being raised.',
#   'news_article_title': 'Should more British homes be built using straw?'},
#  {'news_article_summary': 'The hedges in England would go around Earth ten '
#                           'times.',
#   'news_article_title': "England's hedges would go around Earth ten times"},
#  {'news_article_summary': 'The young science writer award is going national.',
#   'news_article_title': 'Young science writer award goes national'},
#  {'news_article_summary': 'A Japan lander is getting to work on the Moon.',
#   'news_article_title': "'Toy poodles' on the Moon: Japan lander gets to work"},
#  {'news_article_summary': 'There will be mass tree planting to recreate a lost '
#                           'rainforest in Devon.',
#   'news_article_title': 'Mass tree planting to recreate lost rainforest'},
#  {'news_article_summary': "Amazon's record drought is driven by climate "
#                           'change.',
#   'news_article_title': "Amazon's record drought driven by climate change"},
#  {'news_article_summary': 'A new coffee genetic map promises better brews.',
#   'news_article_title': 'New coffee genetic map promises better brews'},
#  {'news_article_summary': "2023 has been confirmed as the world's hottest year "
#                           'on record.',
#   'news_article_title': "2023 confirmed as world's hottest year on record"},
#  {'news_article_summary': 'There is a woman who spends winter in search of a '
#                           'rare fern.',
#   'news_article_title': 'The woman who spends winter in search of a rare fern'},
#  {'news_article_summary': "The impact of COP28's big step forward is being "
#                           'examined.',
#   'news_article_title': "Examining the impact of COP28's big step forward"},
#  {'news_article_summary': 'A European mission has been approved to detect '
#                           'cosmic ripples.',
#   'news_article_title': 'European mission approved to detect cosmic ripples'},
#  {'news_article_summary': 'The mission of Nasa helicopter Ingenuity on Mars '
#                           'has ended due to a crash.',
#   'news_article_title': "Mars crash ends Nasa helicopter Ingenuity's mission"},
#  {'news_article_summary': 'Four new emperor penguin groups have been found by '
#                           'satellite.',
#   'news_article_title': 'Four new emperor penguin groups found by satellite'},
#  {'news_article_summary': 'An American lunar mission has been destroyed over '
#                           'the Pacific Ocean.',
#   'news_article_title': 'American lunar mission destroyed over Pacific Ocean'},
#  {'news_article_summary': 'There are no more Moon men.',
#   'news_article_title': 'The last of the Moon men'},
#  {'news_article_summary': 'People fled as lava spilled into town and they may '
#                           'never return.',
#   'news_article_title': 'They fled as lava spilled into town - and they may '
#                         'never return'},
#  {'news_article_summary': "A 'major' peat restoration project has been "
#                           'completed.',
#   'news_article_title': "'Major' peat restoration project completed"},
#  {'news_article_summary': 'A cyclist rode 160 miles to kick off a football '
#                           'match.',
#   'news_article_title': 'Cyclist rides 160 miles to kick off football match'},
#  {'news_article_summary': 'A worker has marked 40 years at a zoo where she '
#                           'grew up.',
#   'news_article_title': 'Worker marks 40 years at zoo where she grew up'},
#  {'news_article_summary': 'The returnable coffee cup project is expanding into '
#                           'a new city.',
#   'news_article_title': 'Returnable coffee cup project expand into new city'},
#  {'news_article_summary': "A charity aims to restore more of the county's "
#                           'hedgerows.',
#   'news_article_title': "Charity aims to restore more of county's hedgerows"},
#  {'news_article_summary': 'Iron Age and Roman finds are on show after 50 '
#                           'years.',
#   'news_article_title': 'Iron Age and Roman finds on show after 50 years'},
#  {'news_article_summary': "A UK buyer is wanted for the last of Shackleton's "
#                           'medals.',
#   'news_article_title': "UK buyer wanted for last of Shackleton's medals"},
#  {'news_article_summary': 'There is a hunt to uncover the story of a '
#                           'mysterious shipwreck.',
#   'news_article_title': 'Hunt to uncover story of mysterious shipwreck'},
#  {'news_article_summary': "California is bracing for a 'life-threatening' rain "
#                           'storm.',
#   'news_article_title': "California braces for 'life-threatening' rain storm"},
#  {'news_article_summary': 'A nuclear waste facility will blight the community.',
#   'news_article_title': "Nuclear waste facility 'will blight community'"},
#  {'news_article_summary': "Thieves used a Roman fort's scaffolding to steal "
#                           'lead.',
#   'news_article_title': "Thieves use Roman fort's scaffolding to steal lead"},
#  {'news_article_summary': 'Dogs were given oxygen after a flat fire rescue.',
#   'news_article_title': 'Dogs given oxygen after flat fire rescue'},
#  {'news_article_summary': "The zoo's annual animal count reveals 52 births.",
#   'news_article_title': 'Zoo annual animal count reveals 52 births'},
#  {'news_article_summary': 'A boy is set for an Arctic trek in tribute to his '
#                           'father.',
#   'news_article_title': 'Boy set for Arctic trek in tribute to father'},
#  {'news_article_summary': "'Magical things happen where land meets water.'",
#   'news_article_title': "'Magical things happen where land meets water'"}]

# %% [markdown]
# # Web

# %%
# Vectorstore
vectorstore = Chroma(
    embedding_function=OpenAIEmbeddings(), persist_directory="./chroma_db_oai"
)

# LLM
llm = ChatOpenAI(temperature=0)

# Search
search = GoogleSearchAPIWrapper()

# Initialize
web_research_retriever = WebResearchRetriever.from_llm(
    vectorstore=vectorstore, llm=llm, search=search
)

# %%
from langchain.tools import Tool
from langchain_community.utilities import GoogleSearchAPIWrapper

search = GoogleSearchAPIWrapper()

tool = Tool(
    name="Google Search",
    description="Search Google for recent results.",
    func=search.run,
)
temp = tool.run("How do LLM Powered Autonomous Agents work?")

temp
# Out:
# "Jun 23, 2023 ... (1) Task planning: LLM works as the brain and parses the user requests into multiple tasks. There are four attributes associated with each task:\xa0... Jun 28, 2023 ... Hey Lilian, I see you work for OpenAI, maybe you can help. I want to give OpenAI a chance to earn my trust (AI is a concerning subject) so I\xa0... That's how autoregressive LLMs work. GPTs are autoregressive, but it's not the only way an LLM can work. You can also have other types of LLM, like\xa0... Nov 8, 2023 ... In a LLM-powered autonomous agent system, the LLM functions as the agent's brain, complemented by three components: planning, memory and tool\xa0... Sep 27, 2023 ... AutoGPT, GPT-Engineer and BabyAGI are all examples of LLM-powered autonomous agents that drive an underlying LLM to understand the goal they\xa0... Aug 3, 2023 ... An LLM agent is an artificial intelligence system that utilizes a large language model (LLM) as its core computational engine to exhibit\xa0... LLM Powered Autonomous Agents. Building agents with LLM (large language model) ... Feeling a bit intimidating to write about it but work on attacks can lead to\xa0... Oct 9, 2023 ... They harness linguistic reasoning, commonsense knowledge, and actionable insights to deploy particular tools. A single LLM isn't necessarily\xa0... May 7, 2023 ... ... are blog pages that note key research papers. lilianweng.github.io – 23 Jun 23 · LLM Powered Autonomous Agents. Building agents with LLM (large\xa0... Nov 28, 2023 ... ... autonomous agents that work independently to achieve an assigned goal. Unlike stand-alone LLM-based applications that still require humans to\xa0..."

# %%
search = GoogleSearchAPIWrapper()


def top5_results(query):
    return search.results(query, 5)


tool = Tool(
    name="Google Search Snippets",
    description="Search Google for recent results.",
    func=top5_results,
)

# %%
# Out:
# {'context': {'title': 'GOOGLE_CUSTOM_SEARCH'},
#  'items': [{'cacheId': 'gacJvjazw8EJ',
#             'displayLink': 'www.seiko.co.jp',
#             'formattedUrl': 'https://www.seiko.co.jp/csr/magazine/',
#             'htmlFormattedUrl': 'https://www.seiko.co.jp/csr/magazine/',
#             'htmlSnippet': 'Dec 27, 2023 <b>...</b> 9 産業と<b>技術</b>革新の基盤をつくろう '
#                            '産業と<b>技術</b>革新の基盤をつくろう &middot; 11 住み続け ... '
#                            '<b>キーワード</b>から探す &middot; SDGs目標別で見る &middot; '
#                            '<b>サステナブル</b>とは？ セイコーの&nbsp;...',
#             'htmlTitle': '<b>サステナブル</b>・ストーリー | <b>サステナビリティ</b> | セイコーグループ',
#             'kind': 'customsearch#result',
#             'link': 'https://www.seiko.co.jp/csr/magazine/',
#             'pagemap': {'cse_image': [{'src': 'https://www.seiko.co.jp/csr/magazine/images/ogp_csr_magazine.png'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQUfsXWbxLwxrcY352QeB7xRt_RltXAyQt_YBtiem_t9kCR8-dmliayJABt',
#                                            'width': '310'}],
#                         'listitem': [{'item': 'ホーム',
#                                       'name': 'ホーム',
#                                       'position': '1'},
#                                      {'item': 'サステナビリティ',
#                                       'name': 'サステナビリティ',
#                                       'position': '2'},
#                                      {'name': 'サステナブル・ストーリー', 'position': '3'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': 'セイコーグループのサステナブル・ストーリーについてご紹介します。持続可能な社会の発展に貢献し企業価値向上を追求するセイコーグループの取り組みをまとめた記事をご覧いただけます。',
#                                       'og:image': 'https://www.seiko.co.jp/csr/magazine/images/ogp_csr_magazine.png',
#                                       'og:site_name': 'セイコーグループ',
#                                       'og:title': 'サステナブル・ストーリー | サステナビリティ | '
#                                                   'セイコーグループ',
#                                       'og:url': 'https://www.seiko.co.jp/csr/magazine/',
#                                       'viewport': 'width=device-width'}]},
#             'snippet': 'Dec 27, 2023 ... 9 産業と技術革新の基盤をつくろう 産業と技術革新の基盤をつくろう · '
#                        '11 住み続け ... キーワードから探す · SDGs目標別で見る · サステナブルとは？ '
#                        'セイコーの\xa0...',
#             'title': 'サステナブル・ストーリー | サステナビリティ | セイコーグループ'},
#            {'cacheId': 'e9mw--i9BbEJ',
#             'displayLink': 'www.asteria.com',
#             'formattedUrl': 'https://www.asteria.com/jp/inlive/asteria/6414/',
#             'htmlFormattedUrl': 'https://www.asteria.com/jp/inlive/asteria/6414/',
#             'htmlSnippet': 'Dec 1, 2023 <b>...</b> '
#                            '次のステージに向けた成長の<b>キーワード</b>はグローバルと<b>サステナビリティ</b> '
#                            '... '
#                            '世界の分断が進むなか、デジタル<b>技術</b>は新たな形で世界をつなげるきっかけになると思います。',
#             'htmlTitle': '次のステージに向けた成長の<b>キーワード</b>はグローバルと ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.asteria.com/jp/inlive/asteria/6414/',
#             'pagemap': {'breadcrumb': [{'title': 'ホーム', 'url': 'ホーム'},
#                                        {'title': 'アステリア', 'url': 'アステリア'}],
#                         'cse_image': [{'src': 'https://www.asteria.com/jp/inlive/wp-content/uploads/2023/12/0229NIH_0516.jpg'}],
#                         'cse_thumbnail': [{'height': '183',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRZfdnzkpynib6fZQh4aKdWtIlxBPyw6fT-WtcEC3zWgg156gapMqQlMls',
#                                            'width': '275'}],
#                         'metatags': [{'article:modified_time': '2023-12-01T00:30:19+00:00',
#                                       'article:published_time': '2023-12-01T00:00:57+00:00',
#                                       'fb:app_id': '143296222413013',
#                                       'format-detection': 'telephone=no',
#                                       'google': 'nositelinkssearchbox',
#                                       'og:image': 'https://www.asteria.com/jp/inlive/wp-content/uploads/2023/12/0229NIH_0516.jpg',
#                                       'og:image:height': '1667',
#                                       'og:image:secure_url': 'https://www.asteria.com/jp/inlive/wp-content/uploads/2023/12/0229NIH_0516.jpg',
#                                       'og:image:width': '2500',
#                                       'og:locale': 'ja_JP',
#                                       'og:site_name': 'in.LIVE（インライブ）| '
#                                                       '人と技術、未来をつなぐテックメディア',
#                                       'og:title': '次のステージに向けた成長のキーワードはグローバルとサステナビリティ '
#                                                   '| in.LIVE（インライブ）| '
#                                                   '技術と人をつなぐテックメディア',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.asteria.com/jp/inlive/asteria/6414/',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:image': 'https://www.asteria.com/jp/inlive/wp-content/uploads/2023/12/0229NIH_0516.jpg',
#                                       'twitter:title': '次のステージに向けた成長のキーワードはグローバルとサステナビリティ '
#                                                        '| in.LIVE（インライブ）| '
#                                                        '技術と人をつなぐテックメディア',
#                                       'viewport': 'width=device-width,initial-scale=1.0,user-scalable=no'}]},
#             'snippet': 'Dec 1, 2023 ... 次のステージに向けた成長のキーワードはグローバルとサステナビリティ ... '
#                        '世界の分断が進むなか、デジタル技術は新たな形で世界をつなげるきっかけになると思います。',
#             'title': '次のステージに向けた成長のキーワードはグローバルと ...'},
#            {'cacheId': 'b-_tjQoG9MwJ',
#             'displayLink': 'www.sustainability-hub.jp',
#             'formattedUrl': 'https://www.sustainability-hub.jp/column/learn/sustainability',
#             'htmlFormattedUrl': 'https://www.sustainability-hub.jp/column/learn/sustainability',
#             'htmlSnippet': 'Dec 5, 2023 <b>...</b> <b>キーワード</b>. カーボンニュートラル '
#                            '再生可能エネルギー <b>サステナビリティ</b>入門 ... '
#                            '<b>サステナビリティ</b>に関する各分野の要素<b>技術</b>の説明資料、 '
#                            '事例紹介資料、サービス&nbsp;...',
#             'htmlTitle': '企業に求められる<b>サステナビリティ</b>とは？意味や取り組みまで解説 ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.sustainability-hub.jp/column/learn/sustainability',
#             'pagemap': {'cse_image': [{'src': 'https://www.sustainability-hub.jp/media/GXFMmKFEYHPYtZKp4jcJcyShwjZ7wsZG03GmLDXT.png'}],
#                         'cse_thumbnail': [{'height': '167',
#                                            'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcS81k8Su7Tq4trHOjFje8US5NB1WbxXVoP8TIyM4XmZ7jOVhVfH1qTvP2I4',
#                                            'width': '301'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': '近年、よく耳にすることが増えた言葉の一つでもある「サステナビリティ」。今回はサステナビリティの意味や現状と課題、企業が取り組むべき理由までを解説。実際の事例も踏まえて紹介します。',
#                                       'og:image': 'https://www.sustainability-hub.jp/media/GXFMmKFEYHPYtZKp4jcJcyShwjZ7wsZG03GmLDXT.png',
#                                       'og:image:height': '630',
#                                       'og:image:secure_url': 'https://www.sustainability-hub.jp/media/GXFMmKFEYHPYtZKp4jcJcyShwjZ7wsZG03GmLDXT.png',
#                                       'og:image:width': '1200',
#                                       'og:locale': 'ja_JP',
#                                       'og:site_name': 'サステナビリティハブ',
#                                       'og:title': '企業に求められるサステナビリティとは？意味や取り組みまで解説｜サステナビリティハブ',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.sustainability-hub.jp/column/learn/sustainability',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:description': '近年、よく耳にすることが増えた言葉の一つでもある「サステナビリティ」。今回はサステナビリティの意味や現状と課題、企業が取り組むべき理由までを解説。実際の事例も踏まえて紹介します。',
#                                       'twitter:title': '企業に求められるサステナビリティとは？意味や取り組みまで解説｜サステナビリティハブ',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1.0'}]},
#             'snippet': 'Dec 5, 2023 ... キーワード. カーボンニュートラル 再生可能エネルギー サステナビリティ入門 '
#                        '... サステナビリティに関する各分野の要素技術の説明資料、 事例紹介資料、サービス\xa0...',
#             'title': '企業に求められるサステナビリティとは？意味や取り組みまで解説 ...'},
#            {'cacheId': 'qp8OOyahu5EJ',
#             'displayLink': 'www.mitsubishielectric.co.jp',
#             'formattedUrl': 'https://www.mitsubishielectric.co.jp/me/eco_changes/index.html',
#             'htmlFormattedUrl': 'https://www.mitsubishielectric.co.jp/me/eco_changes/index.html',
#             'htmlSnippet': 'Jan 15, 2024 <b>...</b> '
#                            'エコちゃんの“<b>サステナビリティ</b>ですよ。”に断層イメージング<b>技術</b>を追加しました '
#                            '... <b>キーワード</b>集. '
#                            '<b>サステナブル</b>な未来を理解するために、これだけは知っておきたい&nbsp;...',
#             'htmlTitle': '<b>サステナビリティ</b>の広場：三菱電機の取組',
#             'kind': 'customsearch#result',
#             'link': 'https://www.mitsubishielectric.co.jp/me/eco_changes/index.html',
#             'pagemap': {'cse_image': [{'src': 'https://www.mitsubishielectric.co.jp/corporate/sustainability-square/common/img/ogp_square.jpg'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTs-g-oxxZwgBkgTZUIjZM5cx0lNe2EBQ8_F3c3_eDV2sN_ER0lHiHjWdZq',
#                                            'width': '310'}],
#                         'listitem': [{'item': 'トップページ',
#                                       'name': 'トップページ',
#                                       'position': '1'},
#                                      {'item': '企業情報',
#                                       'name': '企業情報',
#                                       'position': '2'},
#                                      {'item': 'サステナビリティ',
#                                       'name': 'サステナビリティ',
#                                       'position': '3'},
#                                      {'item': 'サステナビリティの広場',
#                                       'name': 'サステナビリティの広場',
#                                       'position': '4'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': '次の世代、未来の地球─この先もずっと、笑顔あふれるくらしが続くように。「サステナビリティの広場」では、三菱電機グループの取組とともに、明日をもっとよくする、さまざまな情報を紹介していきます。',
#                                       'og:image': 'https://www.mitsubishielectric.co.jp/corporate/sustainability-square/common/img/ogp_square.jpg',
#                                       'og:site_name': '三菱電機 サステナビリティの広場',
#                                       'og:title': '三菱電機：サステナビリティの広場',
#                                       'og:type': 'website',
#                                       'og:url': 'https://www.mitsubishielectric.co.jp/corporate/sustainability-square/',
#                                       'twitter:card': 'summary_large_image',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'Jan 15, 2024 ... '
#                        'エコちゃんの“サステナビリティですよ。”に断層イメージング技術を追加しました ... キーワード集. '
#                        'サステナブルな未来を理解するために、これだけは知っておきたい\xa0...',
#             'title': 'サステナビリティの広場：三菱電機の取組'},
#            {'cacheId': 'TC-y3lg4cOwJ',
#             'displayLink': 'www.jnc-corp.co.jp',
#             'formattedUrl': 'https://www.jnc-corp.co.jp/sustainability/',
#             'htmlFormattedUrl': 'https://www.jnc-corp.co.jp/sustainability/',
#             'htmlSnippet': 'Jul 2, 2023 <b>...</b> 検索<b>キーワード</b>を入力してください. '
#                            '検索. お問い合わせ. JP. サイトマップ &middot; 関連リンク ... '
#                            '研究開発・生産<b>技術</b> &middot; <b>サステナビリティ</b> &middot; '
#                            '関連リンク &middot; JNC株式会社 &middot; 個人&nbsp;...',
#             'htmlTitle': '<b>サステナビリティ</b> | JNC株式会社',
#             'kind': 'customsearch#result',
#             'link': 'https://www.jnc-corp.co.jp/sustainability/',
#             'pagemap': {'listitem': [{'item': 'HOME',
#                                       'name': 'HOME',
#                                       'position': '1'},
#                                      {'name': 'サステナビリティ', 'position': '2'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'viewport': 'width=device-width,initial-scale=1'}]},
#             'snippet': 'Jul 2, 2023 ... 検索キーワードを入力してください. 検索. お問い合わせ. JP. '
#                        'サイトマップ · 関連リンク ... 研究開発・生産技術 · サステナビリティ · 関連リンク · '
#                        'JNC株式会社 · 個人\xa0...',
#             'title': 'サステナビリティ | JNC株式会社'},
#            {'cacheId': 'Bys_X_cMi94J',
#             'displayLink': 'www.softbank.jp',
#             'formattedUrl': 'https://www.softbank.jp/sbnews/entry/20231108_02',
#             'htmlFormattedUrl': 'https://www.softbank.jp/sbnews/entry/20231108_02',
#             'htmlSnippet': 'Nov 8, 2023 <b>...</b> ... '
#                            '<b>技術</b>です。送受信アンテナを一つずつ使っていた従来に比べて、MIMOは同じ時間と周波数帯域でより多くのデータを送受信することが可能となり通信速度や容量が向上しま&nbsp;...',
#             'htmlTitle': '【MIMO】～1分で分かる<b>キーワード</b> #155 - ITをもっと身近に ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.softbank.jp/sbnews/entry/20231108_02',
#             'pagemap': {'cse_image': [{'src': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_36/20231106/20231106091949.png'}],
#                         'cse_thumbnail': [{'height': '183',
#                                            'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSu3uctACvWZxJAUaFbZV99qAUZbIMMiWVAyOl41knY-6_tmtmrlQGtDIg',
#                                            'width': '275'}],
#                         'hatomfeed': [{}],
#                         'metatags': [{'article:published_time': '1699420554',
#                                       'article:tag': 'IT＆みらい',
#                                       'fb:app_id': '378662655513103',
#                                       'hatena::bookmark': 'nocomment',
#                                       'og:description': '複数のアンテナを用いて周波数利用の効率化を図り、データ送受信において通信の品質向上を実現した無線通信技術のこと '
#                                                         '複数の送受信アンテナにより通信品質が向上 '
#                                                         'MIMO（マイモ）はMulti-Input '
#                                                         'Multi-Outputの略称で、複数のアンテナで同時にデータを送受信し、通信容量を増やす無線通信技術です。送受信アンテナを一つずつ使っていた従来に比べて、MIMOは同じ時間と周波数帯域でより多くのデータを送受信することが可能となり通信速度や容量が向上しました。 '
#                                                         'また、MIMOをより高度化させた5Gの要素技術Massive '
#                                                         'MIMO（マッシブ・マイモ）は、多数のアンテナを使用してビームフォーミング（…',
#                                       'og:image': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_36/20231106/20231106091949.png',
#                                       'og:image:alt': '【MIMO】～1分で分かるキーワード #155 '
#                                                       '- ITをもっと身近に。ソフトバンクニュース',
#                                       'og:site_name': 'ITをもっと身近に。ソフトバンクニュース',
#                                       'og:title': '【MIMO】～1分で分かるキーワード #155 - '
#                                                   'ITをもっと身近に。ソフトバンクニュース',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.softbank.jp/sbnews/entry/20231108_02',
#                                       'twitter:app:id:iphone': '583299321',
#                                       'twitter:app:name:iphone': 'はてなブログアプリ',
#                                       'twitter:app:url:iphone': 'hatenablog:///open?uri=https%3A%2F%2Fwww.softbank.jp%2Fsbnews%2Fentry%2F20231108_02',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:description': '複数のアンテナを用いて周波数利用の効率化を図り、データ送受信において通信の品質向上を実現した無線通信技術のこと '
#                                                              '複数の送受信アンテナにより通信品質が向上 '
#                                                              'MIMO（マイモ）はMulti-Input '
#                                                              'Multi-Outputの略称で、複数のアンテナで同時にデータを送受信し、通信容量を増やす無線通信技術です。送受信アンテナ…',
#                                       'twitter:image': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_36/20231106/20231106091949.png',
#                                       'twitter:site': '@SoftBank',
#                                       'twitter:title': '【MIMO】～1分で分かるキーワード '
#                                                        '#155 - '
#                                                        'ITをもっと身近に。ソフトバンクニュース',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}],
#                         'sitenavigationelement': [{'name': 'トレンド情報',
#                                                    'url': 'トレンド情報'}]},
#             'snippet': 'Nov 8, 2023 ... ... '
#                        '技術です。送受信アンテナを一つずつ使っていた従来に比べて、MIMOは同じ時間と周波数帯域でより多くのデータを送受信することが可能となり通信速度や容量が向上しま\xa0'
#                        '...',
#             'title': '【MIMO】～1分で分かるキーワード #155 - ITをもっと身近に ...'},
#            {'cacheId': 'oO4ck4RFcX8J',
#             'displayLink': 'www.nisshin-oillio.com',
#             'formattedUrl': 'https://www.nisshin-oillio.com/company/csr/',
#             'htmlFormattedUrl': 'https://www.nisshin-oillio.com/company/csr/',
#             'htmlSnippet': 'Jan 12, 2024 <b>...</b> ... '
#                            '<b>技術</b>力を活かした多彩な商品を提供しています。日清オイリオグループ（株）の企業情報、事業活動、採用情報、IR情報、<b>技術</b> '
#                            '... <b>キーワード</b>で見る. すべての人の健康. 01&nbsp;...',
#             'htmlTitle': '<b>サステナビリティ</b>｜ 植物のチカラ 日清オイリオ',
#             'kind': 'customsearch#result',
#             'link': 'https://www.nisshin-oillio.com/company/csr/',
#             'pagemap': {'cse_image': [{'src': 'http://www.nisshin-oillio.com/ogp/ogp.png'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSMfXkJotnFhejrRc_U-CjpUt_cDbymHR5woqS8tb3FAkxuv9GQI7XgGgHz',
#                                            'width': '310'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': '植物のチカラ\u3000'
#                                                         '日清オイリオグループ（株）のホームページです。日本で初のサラダ油、「日清サラダ油」を製造・発売するなど、食用油のリーディングカンパニーとして常に技術力を活かした多彩な商品を提供しています。日清オイリオグループ（株）の企業情報、事業活動、採用情報、ＩＲ情報、技術・研究をご紹介します。',
#                                       'og:image': 'http://www.nisshin-oillio.com/ogp/ogp.png',
#                                       'og:locale': 'ja_JP',
#                                       'og:site_name': '植物のチカラ\u3000日清オイリオ',
#                                       'og:title': 'サステナビリティ｜植物のチカラ\u3000日清オイリオ',
#                                       'og:type': 'website',
#                                       'og:url': 'http://www.nisshin-oillio.com/company/sustainability/',
#                                       'viewport': 'width=device-width'}]},
#             'snippet': 'Jan 12, 2024 ... ... '
#                        '技術力を活かした多彩な商品を提供しています。日清オイリオグループ（株）の企業情報、事業活動、採用情報、IR情報、技術 '
#                        '... キーワードで見る. すべての人の健康. 01\xa0...',
#             'title': 'サステナビリティ｜ 植物のチカラ 日清オイリオ'},
#            {'cacheId': 'kziHnShb5eEJ',
#             'displayLink': 'www.softbank.jp',
#             'formattedUrl': 'https://www.softbank.jp/sbnews/entry/20230915_02',
#             'htmlFormattedUrl': 'https://www.softbank.jp/sbnews/entry/20230915_02',
#             'htmlSnippet': 'Sep 15, 2023 <b>...</b> '
#                            'ハッカソンとはエンジニアやプログラマーなどの<b>技術</b>者が集まり、集中的にアプリやシステムの開発を行ったり成果を発表したりするイベントのこと.',
#             'htmlTitle': '【ハッカソン】～1分で分かる<b>キーワード</b> #138 - ITをもっと身近に ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.softbank.jp/sbnews/entry/20230915_02',
#             'pagemap': {'cse_image': [{'src': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_29/20230912/20230912114421.png'}],
#                         'cse_thumbnail': [{'height': '183',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTI-Dmh8oT72qlLLXRAcTQYzyIGS3J83CVY1VS4lpTbQ4RiogW3Bt3qgUU',
#                                            'width': '275'}],
#                         'hatomfeed': [{}],
#                         'metatags': [{'article:published_time': '1694757600',
#                                       'article:tag': 'IT＆みらい',
#                                       'fb:app_id': '378662655513103',
#                                       'hatena::bookmark': 'nocomment',
#                                       'og:description': 'ハッカソンとはエンジニアやプログラマーなどの技術者が集まり、集中的にアプリやシステムの開発を行ったり成果を発表したりするイベントのこと',
#                                       'og:image': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_29/20230912/20230912114421.png',
#                                       'og:image:alt': '【ハッカソン】～1分で分かるキーワード '
#                                                       '#138 - '
#                                                       'ITをもっと身近に。ソフトバンクニュース',
#                                       'og:site_name': 'ITをもっと身近に。ソフトバンクニュース',
#                                       'og:title': '【ハッカソン】～1分で分かるキーワード #138 - '
#                                                   'ITをもっと身近に。ソフトバンクニュース',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.softbank.jp/sbnews/entry/20230915_02',
#                                       'twitter:app:id:iphone': '583299321',
#                                       'twitter:app:name:iphone': 'はてなブログアプリ',
#                                       'twitter:app:url:iphone': 'hatenablog:///open?uri=https%3A%2F%2Fwww.softbank.jp%2Fsbnews%2Fentry%2F20230915_02',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:description': 'ハッカソンとはエンジニアやプログラマーなどの技術者が集まり、集中的にアプリやシステムの開発を行ったり成果を発表したりするイベントのこと',
#                                       'twitter:image': 'https://cdn-ak.f.st-hatena.com/images/fotolife/s/sbn_29/20230912/20230912114421.png',
#                                       'twitter:site': '@SoftBank',
#                                       'twitter:title': '【ハッカソン】～1分で分かるキーワード '
#                                                        '#138 - '
#                                                        'ITをもっと身近に。ソフトバンクニュース',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}],
#                         'sitenavigationelement': [{'name': 'トレンド情報',
#                                                    'url': 'トレンド情報'}]},
#             'snippet': 'Sep 15, 2023 ... '
#                        'ハッカソンとはエンジニアやプログラマーなどの技術者が集まり、集中的にアプリやシステムの開発を行ったり成果を発表したりするイベントのこと.',
#             'title': '【ハッカソン】～1分で分かるキーワード #138 - ITをもっと身近に ...'},
#            {'cacheId': 'russA7-HQIUJ',
#             'displayLink': 'www.jmac.co.jp',
#             'formattedUrl': 'https://www.jmac.co.jp/column/detail/Insights_75_col_shimini.html',
#             'htmlFormattedUrl': 'https://www.jmac.co.jp/column/detail/Insights_75_col_shimini.html',
#             'htmlSnippet': 'Aug 2, 2023 <b>...</b> '
#                            '今の日本企業は日本らしい<b>サステナビリティ</b>経営によって、世界をリードすべきとき。 ... '
#                            'イノベーションで成果を出す<b>技術</b>人材をつくるには '
#                            '〜カギは「場づくり」と「仕掛け&nbsp;...',
#             'htmlTitle': '日本企業の未来を握る「シン・市民主義経営」4つの<b>キーワード</b> ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.jmac.co.jp/column/detail/Insights_75_col_shimini.html',
#             'pagemap': {'cse_image': [{'src': 'https://www.jmac.co.jp/column/items/col_shimini_opg.webp'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRl-9DjFVTodJpbY0-xE27aASim--1v__Nj-oGIdCaQWYZ_zRPbR5lS0Fz8',
#                                            'width': '310'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': '日本能率協会コンサルティング（JMAC）のコンサルタントがコンサルティングの現場で得た経験や知見、問題解決の視点などをコラムで紹介します。',
#                                       'og:image': 'https://www.jmac.co.jp/column/items/col_shimini_opg.webp',
#                                       'og:locale': 'ja_jp',
#                                       'og:site_name': '株式会社 日本能率協会コンサルティング',
#                                       'og:title': '日本企業の未来を握る「シン・市民主義経営」４つのキーワード '
#                                                   '| コラム | 株式会社 日本能率協会コンサルティング',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.jmac.co.jp/column/detail/Insights_75_col_shimini.html',
#                                       'twitter:card': 'summary_large_image',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1, '
#                                                   'viewport-fit=cover'}]},
#             'snippet': 'Aug 2, 2023 ... '
#                        '今の日本企業は日本らしいサステナビリティ経営によって、世界をリードすべきとき。 ... '
#                        'イノベーションで成果を出す技術人材をつくるには 〜カギは「場づくり」と「仕掛け\xa0...',
#             'title': '日本企業の未来を握る「シン・市民主義経営」4つのキーワード ...'},
#            {'cacheId': 'SFUZprEGibsJ',
#             'displayLink': 'www.jri.co.jp',
#             'formattedUrl': 'https://www.jri.co.jp/page.jsp?id=105726',
#             'htmlFormattedUrl': 'https://www.jri.co.jp/page.jsp?id=105726',
#             'htmlSnippet': 'Jul 24, 2023 <b>...</b> '
#                            '調査した環境関連<b>キーワード</b>の中で最も記載が多かったものは71社が言及した「TCFD」であった。改正内容として「ガバナンス」「戦略」「リスク管理」「指標と目標」などの&nbsp;...',
#             'htmlTitle': '【日本総研 <b>サステナビリティ</b>・人的資本 情報開示状況調査（2023 ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.jri.co.jp/page.jsp?id=105726',
#             'pagemap': {'cse_image': [{'src': 'https://www.jri.co.jp/image/r1/common/ogp.png'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRFthoNV8WmqgS_owu7fYIbjgdN-nNRbK0esHLMLHgu4WEdtwCWJs8fyv4',
#                                            'width': '310'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': '日本総合研究所は、システムインテグレーション・コンサルティング・シンクタンクの3つの機能を有する総合情報サービス企業です。',
#                                       'og:image': 'https://www.jri.co.jp/image/r1/common/ogp.png',
#                                       'og:site_name': '日本総研',
#                                       'og:title': '【日本総研\u3000サステナビリティ・人的資本 '
#                                                   '情報開示状況調査（2023年度）】第2回\u3000'
#                                                   'サステナビリティ編①｜日本総研',
#                                       'og:type': 'website',
#                                       'og:url': 'https://www.jri.co.jp/page.jsp?id=105726',
#                                       'viewport': 'width=device-width,initial-scale=1.0,minimum-scale=1.0'}]},
#             'snippet': 'Jul 24, 2023 ... '
#                        '調査した環境関連キーワードの中で最も記載が多かったものは71社が言及した「TCFD」であった。改正内容として「ガバナンス」「戦略」「リスク管理」「指標と目標」などの\xa0'
#                        '...',
#             'title': '【日本総研 サステナビリティ・人的資本 情報開示状況調査（2023 ...'}],
#  'kind': 'customsearch#search',
#  'queries': {'nextPage': [{'count': 10,
#                            'cx': '078e47d6222df4a2e',
#                            'inputEncoding': 'utf8',
#                            'outputEncoding': 'utf8',
#                            'safe': 'off',
#                            'searchTerms': 'サステナビリティ 技術 キーワード after:2023/07/01',
#                            'startIndex': 11,
#                            'title': 'Google Custom Search - サステナビリティ 技術 キーワード '
#                                     'after:2023/07/01',
#                            'totalResults': '79200'}],
#              'request': [{'count': 10,
#                           'cx': '078e47d6222df4a2e',
#                           'inputEncoding': 'utf8',
#                           'outputEncoding': 'utf8',
#                           'safe': 'off',
#                           'searchTerms': 'サステナビリティ 技術 キーワード after:2023/07/01',
#                           'startIndex': 1,
#                           'title': 'Google Custom Search - サステナビリティ 技術 キーワード '
#                                    'after:2023/07/01',
#                           'totalResults': '79200'}]},
#  'searchInformation': {'formattedSearchTime': '0.54',
#                        'formattedTotalResults': '79,200',
#                        'searchTime': 0.541861,
#                        'totalResults': '79200'},
#  'url': {'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json',
#          'type': 'application/json'}}

# %%
# Run
import logging
from langchain.chains import RetrievalQAWithSourcesChain

logging.basicConfig()
logging.getLogger("langchain.retrievers.web_research").setLevel(logging.INFO)

user_input = "How do LLM Powered Autonomous Agents work?"
qa_chain = RetrievalQAWithSourcesChain.from_chain_type(
    llm, retriever=web_research_retriever
)
result = qa_chain({"question": user_input})
result
# Out:
# c:\Users\tmina\anaconda3\envs\myenv\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# INFO:langchain.retrievers.web_research:Generating questions for Google Search ...
# INFO:langchain.retrievers.web_research:Questions for Google Search (raw): {'question': 'How do LLM Powered Autonomous Agents work?', 'text': LineList(lines=['1. What is the functioning principle of LLM Powered Autonomous Agents?\n', '2. How do LLM Powered Autonomous Agents operate?\n', '3. Can you explain the working mechanism of LLM Powered Autonomous Agents?'])}
# INFO:langchain.retrievers.web_research:Questions for Google Search: ['1. What is the functioning principle of LLM Powered Autonomous Agents?\n', '2. How do LLM Powered Autonomous Agents operate?\n', '3. Can you explain the working mechanism of LLM Powered Autonomous Agents?']
# INFO:langchain.retrievers.web_research:Searching for relevant urls...
# INFO:langchain.retrievers.web_research:Searching for relevant urls...
# INFO:langchain.retrievers.web_research:Search results: [{'title': "LLM Powered Autonomous Agents | Lil'Log", 'link': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'snippet': 'Jun 23, 2023 ... 1. Overview of a LLM-powered autonomous agent system. Component One: Planning#. A complicated task usually involves many steps. An agent needs\xa0...'}]
# INFO:langchain.retrievers.web_research:Searching for relevant urls...
# INFO:langchain.retrievers.web_research:Search results: [{'title': "LLM Powered Autonomous Agents | Lil'Log", 'link': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'snippet': 'Jun 23, 2023 ... (1) Task planning: LLM works as the brain and parses the user requests into multiple tasks. There are four attributes associated with each task:\xa0...'}]
# INFO:langchain.retrievers.web_research:Searching for relevant urls...
# INFO:langchain.retrievers.web_research:Search results: [{'title': "LLM Powered Autonomous Agents | Lil'Log", 'link': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'snippet': 'Jun 23, 2023 ... Overview of a LLM-powered autonomous agent system. Component One: Planning#. A complicated task usually involves many steps. An agent needs to\xa0...'}]
# INFO:langchain.retrievers.web_research:New URLs to load: ['https://lilianweng.github.io/posts/2023-06-23-agent/']
# INFO:langchain.retrievers.web_research:Indexing new urls...
# Fetching pages: 100%|##########| 1/1 [00:00<00:00,  4.19it/s]
# INFO:langchain.retrievers.web_research:Grabbing most relevant splits from urls...
# {'question': 'How do LLM Powered Autonomous Agents work?',
#  'answer': "LLM-powered autonomous agents work by utilizing LLM as the agent's brain, along with several key components such as planning, memory, and tool use. In terms of planning, the agent breaks down large tasks into smaller subgoals and can reflect on past actions to improve future results. The agent also utilizes short-term and long-term memory to learn and retain information. Additionally, the agent can call external APIs for additional information. The design of generative agents combines LLM with memory, planning, and reflection mechanisms to enable agents to behave based on past experience and interact with other agents.\n",
#  'sources': ''}

# %%
index_creator = GraphIndexCreator(llm=OpenAI(temperature=0))

# %%
text = 'It won’t look like much, but if you stop and look closely, you’ll see a “Field of dreams,” the ground on which America’s future will be built. \nThis is where Intel, the American company that helped build Silicon Valley, is going to build its $20 billion semiconductor “mega site”. \nUp to eight state-of-the-art factories in one place. 10,000 new good-paying jobs. '

# %%
graph = index_creator.from_text(text)

# %%
chain = GraphQAChain.from_llm(OpenAI(temperature=0), graph=graph, verbose=True)

chain.run("what is Intel going to build?")
# Out:
# > Entering new GraphQAChain chain...
# Entities Extracted:
#  Intel
# Full Context:
# Intel is going to build $20 billion semiconductor “mega site”
# Intel helped build Silicon Valley
# Intel is going to build up to eight state-of-the-art factories
# Intel is going to create 10,000 new good-paying jobs
# Intel is located in America
#
# > Finished chain.
# ' Intel is going to build a $20 billion semiconductor "mega site" and up to eight state-of-the-art factories.'
